# %%
import pandas as pd

df = pd.read_csv("camera_dataset.tsv", delimiter="\t", on_bad_lines="skip")
print(df.head())

# list the columns
df.columns

# list the unique values for column "product_category"
df["product_category"].unique()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US      2975964  R1NBG94582SJE2  B00I01JQJM       860486164
# 1          US     23526356  R273DCA6Y0H9V7  B00TCO0ZAA       292641483
# 2          US     52764145   RQVOXO7WUOFK6  B00B7733E0        75825744
# 3          US     47348933  R1KWKSF21PO6HO  B006ZN4U34       789352955
# 4          US     33680700  R38H3UO1J190GI  B00HUEBGMU        19067902
#
#                                        product_title product_category  \
# 0  GoPro Rechargeable Battery 2.0 (HERO3/HERO3+ o...           Camera
# 1  Professional 58mm Center Pinch Lens Cap for CA...           Camera
# 2  Spy Tec Z12 Motion Activated Intelligent Secur...           Camera
# 3  Celestron UpClose G2 10x25 Monocular, Black (7...           Camera
# 4  Vidpro XM-L Wired Lavalier microphone - 20' Au...           Camera
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            2              1            1    N                 Y
# 3            5              0            0    N                 Y
# 4            5              1            1    N                 Y
#
#                                 review_headline  \
# 0                                    Five Stars
# 1                                    Love it!!!
# 2                    Another Motion Detect Fail
# 3           Exactly what I wanted and expected.
# 4  Good mic at a Good Price...Not Canon Though.
#
#                                          review_body review_date
# 0                                                 ok  2015-08-31
# 1          Perfect, even sturdier than the original!  2015-08-31
# 2  If the words, &#34;Cheap Chinese Junk&#34; com...  2015-08-31
# 3  Exactly what I wanted and expected. Perfect fo...  2015-08-31
# 4  I will look past the fact that they tricked me...  2015-08-31
# array(['Camera'], dtype=object)

# %%
#remove all rows that have a null value in column "product_category" for dataframe df
df_remove_null = df.dropna(subset=["product_category"])

#count the rows for dataframe df
df_remove_null.count()
# Out:
# marketplace          1800845
# customer_id          1800845
# review_id            1800845
# product_id           1800845
# product_parent       1800845
# product_title        1800845
# product_category     1800845
# star_rating          1800845
# helpful_votes        1800845
# total_votes          1800845
# vine                 1800845
# verified_purchase    1800845
# review_headline      1800827
# review_body          1800753
# review_date          1800836
# dtype: int64

# %%
# count how many rows in dataframe df have the value "[null]" in the column "product_category"
null_count = df[df['product_category'] == '-'].shape[0]
# Print the result
print(f"Number of rows with '[null]' value: {null_count}")
# Out:
# Number of rows with '[null]' value: 0

# %%
# Columns we need: customer_id, product_id, product_title, product_category, star_rating, total_votes, vine, verified_purchase, review_headline, review_body

trimmed_df = df[["customer_id", "product_id", "product_title", "star_rating", "helpful_votes", "total_votes", "vine", "verified_purchase", "review_headline", "review_body"]]

# %%
trimmed_df.head(50)
# Out:
#     customer_id  product_id  \
# 0       2975964  B00I01JQJM
# 1      23526356  B00TCO0ZAA
# 2      52764145  B00B7733E0
# 3      47348933  B006ZN4U34
# 4      33680700  B00HUEBGMU
# 5      30301059  B008MW6Y12
# 6      28282645  B00TE8XKIS
# 7        502818  B00ZKDUFBQ
# 8       1481233  B010BZ7S2Q
# 9      27885926  B00HRXSSRA
# 10      3183883  B005C95NM4
# 11     23208852  B00LBIBYBE
# 12     11438825  B00X3HIM2U
# 13     50399582  B00KDVQF8W
# 14     36700181  B00GUZEZL4
# 15     47818374  B00FB1TBKS
# 16     35272750  B00GVMLPT6
# 17     11736306  B00L8827BI
# 18     52377008  B00SIM78R0
# 19      6465510  B00EDCZKJ2
# 20     16433265  B008SFPMRK
# 21     11402392  B00XZGBW44
# 22     50510428  B00MENDBKC
# 23     25247114  B009KY5YYO
# 24     41938409  B00YQ887FC
# 25     36323480  B002CGSYNA
# 26     13649601  B001VGJ4DG
# 27     22125044  B0046C8BWM
# 28     40291324  B00GMRUEMY
# 29     35386096  B00JTE50US
# 30      6475102  B00XC46RWG
# 31     12354360  B00KCX8H6E
# 32     52859599  B002GUF90I
# 33     10382518  B00RRD1IFO
# 34       109519  B003F7DWH8
# 35     41405153  B00CD6DD1M
# 36     51218273  B00009UT3F
# 37     38799200  B00603RTCI
# 38     46588192  B00A7AY3WE
# 39     19216255  B00T98SO0C
# 40     49652941  B0036SYSJ2
# 41     26516524  B00MJA5OJ6
# 42     15899329  B0046V58Y2
# 43     13720995  B00AXTQRAA
# 44     38680316  B00I3LSCQW
# 45     26680197  B00SW25AIA
# 46     45572128  B00GRCZOGU
# 47     29739494  B00TXM8CWY
# 48     27376999  B005IAXVMG
# 49     14432510  B00B7FNHNO
#
#                                         product_title  star_rating  \
# 0   GoPro Rechargeable Battery 2.0 (HERO3/HERO3+ o...            5
# 1   Professional 58mm Center Pinch Lens Cap for CA...            5
# 2   Spy Tec Z12 Motion Activated Intelligent Secur...            2
# 3   Celestron UpClose G2 10x25 Monocular, Black (7...            5
# 4   Vidpro XM-L Wired Lavalier microphone - 20' Au...            5
# 5   NIX 8 inch Hi-Res Digital Photo Frame with Mot...            3
# 6             Polaroid ZIP Mobile Printer Parent ASIN            3
# 7   GeekPro 2.0-Inch WIFI HD 1080P 12MP Sports Cam...            5
# 8   Sony HDR-AZ1VR Action Cam Mini Camcorder 1080p...            5
# 9   ChiliPower DMW-BLC12, DMW-BLC12E, DMW-BLC12PP ...            1
# 10  Zeikos Deluxe Flash Bracket for DSLR and Point...            4
# 11                                 GoPro Hero Filters            5
# 12  Neewer Meike MK-XT1 Battery Grip (Replacement ...            3
# 13  LB Photography Backdrop Vinyl Customized Child...            5
# 14  Waterproof Camera Float (2-pack) Floating Came...            5
# 15  Ecolink Z-Wave PIR Motion Detector, Pet Immune...            5
# 16  FotoTech Male to Male M-M FLASH PC Sync Cable ...            2
# 17  Nikon D3200 Ultimate 4 Lens Experience include...            5
# 18  D-Link Wireless Day/Night WiFi Network Surveil...            4
# 19  ZINK Phone Photo & Labels Wireless Printer. Wi...            1
# 20  Wasabi Power Battery (2-Pack) and Charger for ...            4
# 21  Sricam SP720 Plug & Play Wireless IP Camera 72...            1
# 22  Samsung Galaxy GC110 Camera with Android 4.1 J...            4
# 23      Ape Case Professional Lens Case, Black/Yellow            5
# 24  ActionPro-X Bundle - 1080p Full HD Wifi Sports...            4
# 25  Olympus VF-1 Optical Viewfinder for use with O...            5
# 26  Pioneer Photo Albums STC-504/NB 3-Ring Photo A...            4
# 27  57" Tripod Kit For The Canon SX510 HS, SX520 H...            1
# 28    (Create a generic Title per Amazons guidelines)            5
# 29  Waterproof Camera Float (2-pack) Floating Came...            5
# 30  Lightdow LD6000 WiFi 1080P HD Sports Action Ca...            5
# 31                      GoPro 3-Way Grip, Arm, Tripod            5
# 32  Nikon ML-L3 Remote Control for Nikon D40, D40x...            1
# 33  WoCase GoPro Frame and Lens Accessory Collecti...            5
# 34         Case Logic DCB-302 Compact Camera Case Red            5
# 35  Gear-Pro High-Definition Sport Action Camera,7...            2
# 36                              Sunpak 620-080 Tripod            4
# 37  AGFA 3-Piece Professional Filter Kit Ultraviol...            5
# 38                                                  -            3
# 39  eSecure NVPT0A P2P Wireless IP Pan/Tilt/ Night...            5
# 40                    NB-4L Battery Charger For Canon            5
# 41  Panasonic Lumix DMC-FZ1000 4K QFHD/HD 16X Long...            5
# 42  Wasabi Power Battery and Charger for Canon BP-...            3
# 43                            Nikon D5200 Digital SLR            5
# 44  iVUE Crossfire 720P HD Action Camera Glasses S...            4
# 45  Nikon D7100 Digital SLR Camera Body 33rd Stree...            5
# 46  2x Pack - Fujifilm X-E1 Battery + Charger - Re...            5
# 47  Panasonic Lumix DMC-GH4 4K Micro Four Thirds D...            1
# 48  Dicapac WP-ONE Point & Shoot Digital Camera Wa...            4
# 49  Panasonic Lumix DMC-ZS30(DMC-TZ40) Digital Cam...            3
#
#     helpful_votes  total_votes vine verified_purchase  \
# 0               0            0    N                 Y
# 1               0            0    N                 Y
# 2               1            1    N                 Y
# 3               0            0    N                 Y
# 4               1            1    N                 Y
# 5               0            0    N                 Y
# 6               8            8    N                 N
# 7               0            1    N                 Y
# 8               0            2    N                 Y
# 9               0            0    N                 Y
# 10              1            1    N                 Y
# 11              0            0    N                 Y
# 12              3            3    N                 Y
# 13              4            4    N                 Y
# 14              0            0    N                 Y
# 15              0            0    N                 Y
# 16              0            0    N                 Y
# 17              0            0    N                 Y
# 18              0            0    N                 Y
# 19              1            3    N                 N
# 20              0            1    N                 Y
# 21              0            0    N                 Y
# 22              1            1    N                 Y
# 23              4            4    N                 Y
# 24              3            4    N                 Y
# 25              0            0    N                 Y
# 26              0            0    N                 Y
# 27              0            0    N                 Y
# 28              0            0    N                 Y
# 29              0            0    N                 Y
# 30              6            8    N                 Y
# 31              0            0    N                 Y
# 32              0            0    N                 Y
# 33              0            0    N                 Y
# 34              0            0    N                 N
# 35              0            0    N                 Y
# 36              0            0    N                 Y
# 37              0            0    N                 Y
# 38              0            0    N                 Y
# 39              1            1    N                 Y
# 40              0            0    N                 Y
# 41              0            0    N                 Y
# 42              0            1    N                 Y
# 43              0            0    N                 Y
# 44              0            0    N                 Y
# 45              0            0    N                 Y
# 46              0            0    N                 Y
# 47             13           14    N                 Y
# 48              0            0    N                 Y
# 49              1            1    N                 Y
#
#                                       review_headline  \
# 0                                          Five Stars
# 1                                          Love it!!!
# 2                          Another Motion Detect Fail
# 3                 Exactly what I wanted and expected.
# 4        Good mic at a Good Price...Not Canon Though.
# 5   The controls are pretty slow, and I can't get ...
# 6   Fun toy for making stickers, but expensive to ...
# 7                                          Five Stars
# 8                                          Five Stars
# 9                                              Sucky.
# 10       Hand Hold Bracket For Off Center Flash Unit.
# 11                                         Five Stars
# 12                            Can't grip the battery.
# 13                   Super pleased with this backdrop
# 14                                   Excellent value!
# 15                                      great product
# 16                                          Two Stars
# 17                                         Five Stars
# 18        Nice camera, not as sharp as previous model
# 19                                       Never Agian.
# 20                         Good batteries and charger
# 21                                                BAD
# 22  Perfect size for concerts!  Needs Microphone t...
# 23                  Inexpensive large lens carry case
# 24  I love the camera but it is missing a very imp...
# 25                                  Somewhat helpful.
# 26                                       Great price!
# 27                                 Don't get suckered
# 28                                         Five Stars
# 29                 A Must Have For Waterproof Cameras
# 30                          Perfect GoPro Alternative
# 31                                         Five Stars
# 32                                                Dud
# 33                                         Five Stars
# 34                                  I had to get this
# 35              sound is bad, color at night is fuzzy
# 36                                         Four Stars
# 37                                        Good value.
# 38                                        Three Stars
# 39       For a domestic use it is hihgly recommended.
# 40                      Great charger at a good price
# 41                                         Five Stars
# 42            it works, but no power level indicator.
# 43  This is a great camera. I take it everywhere w...
# 44                  Image is good. Works as described
# 45  Camera and they were very nice. helped me out ...
# 46                                         Five Stars
# 47       Did not get what was promised! This is a ...
# 48                             Worth it for the price
# 49                                        Three Stars
#
#                                           review_body
# 0                                                  ok
# 1           Perfect, even sturdier than the original!
# 2   If the words, &#34;Cheap Chinese Junk&#34; com...
# 3   Exactly what I wanted and expected. Perfect fo...
# 4   I will look past the fact that they tricked me...
# 5   The controls are pretty slow, and I can't get ...
# 6   The printer came in a small fairly plain box w...
# 7                         Great camera for the price.
# 8   Product is very good and satisfactory.<br /><b...
# 9   Lasted a few hours with its first charge, whic...
# 10  I needed the flash unit to be off center from ...
# 11                            Use these all the time.
# 12  Same issue as others the battery won't stay la...
# 13  Super pleased with this backdrop!!! Put it up ...
# 14  These float wristbands for holding camera are ...
# 15                very good on batteries, recommended
# 16  im not happy, the cable gets out. need a stron...
# 17      It is a very good starter set for this camera
# 18  Nice camera for the price. Be aware that it co...
# 19  If I could leave a 0 I would, I was so excited...
# 20  This recharges batteries quickly. I purchased ...
# 21  Not usable due to its a new product and not re...
# 22  This was one of the best purchases I have ever...
# 23  Well padded very large case.  Large enough to ...
# 24  I love the camera but it is missing a very imp...
# 25  Works well, however if you zoom into scene, th...
# 26                        Great price for what u get!
# 27  The second or third time I used it one leg ben...
# 28  Fit and worked perfectly and super fast shipping!
# 29  I purchased this product for my Olympus TG-4 b...
# 30  Absolutely love this product, for $80 it's imp...
# 31        Great product, very useful. Does not flote.
# 32      It never worked.  I should have sent it back.
# 33                                  Good as described
# 34  Love at first sight. This is an amazing case a...
# 35  sound is bad, color at night is fuzzy, hd reco...
# 36                                        WORKS WELL.
# 37                       Quality and price very good.
# 38            There okay, use them here and there....
# 39  Exactly what I was expecting. For a domestic u...
# 40                      Great charger at a good price
# 41   Very good camera great photos very good 4k video
# 42  No power level indicator. not that  most 3rd p...
# 43  This is a great camera. I take it everywhere w...
# 44  Works very well.  Give one a &#34;you are ther...
# 45  Camera was just as advertised.  It was deliver...
# 46  The product was received as displayed and in a...
# 47  Did not get what was promised! This is a scam,...
# 48  Lens seemed to get a little foggy, but easily ...
# 49                                     Ok for a gift!

# %%
# count rows with more than 0 helpful_votes
count = (trimmed_df['helpful_votes'] > 0).sum()
print(count)
# Out:
# 707547

# %%
count = (trimmed_df['total_votes'] > 0).sum()
print(count)
# Out:
# 843673

# %%
# random sampler to pull 10,000 rows from trimmed_df

random_sample = trimmed_df.sample(n=10000)

count = random_sample[random_sample['star_rating'] == 1].shape[0]
print(f"Number of rows = 1: {count}")
# Out:
# Number of rows = 1: 942

# %%
# def get_random_samples(df, n=5, frac=None, replace=False, random_state=None):
#   return df.sample(n=n, frac=frac, replace=replace, random_state=random_state)

# random_sample2 = get_random_samples(trimmed_df,n=10000)

# count = random_sample2[random_sample2['star_rating'] == 5].shape[0]
# print(f"Number of rows = 5: {count}")
random_sample.columns
#remove all null values from "review_body" and "review_headline" columns for random sample
random_sample = random_sample.dropna(subset=['review_body', 'review_headline'])

# %%
from nltk.corpus import stopwords
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from transformers import GPT2Tokenizer, GPT2Model

# Initialize GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

random_sample['review_body'] = random_sample['review_body'].str.lower()
random_sample['review_body'] = random_sample['review_body'].str.replace('[^\w\s]','')
random_sample['review_body'] = random_sample['review_body'].str.replace('\d+', '')

random_sample['review_headline'] = random_sample['review_headline'].str.lower()
random_sample['review_headline'] = random_sample['review_headline'].str.replace('[^\w\s]','')
random_sample['review_headline'] = random_sample['review_headline'].str.replace('\d+', '')

stop_words = set(stopwords.words('english'))
random_sample['review_body'] = random_sample['review_body'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
random_sample['review_headline'] = random_sample['review_headline'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

random_sample['review_body'] = random_sample['review_body'].apply(lambda x: ' '.join([word for word in x.split() if len(word)>2]))
random_sample['review_headline'] = random_sample['review_headline'].apply(lambda x: ' '.join([word for word in x.split() if len(word)>2]))


random_sample['review_body_tokens'] = random_sample['review_body'].apply(lambda x: tokenizer.tokenize(x) if isinstance(x, str) else [])
random_sample['review_headline_tokens'] = random_sample['review_headline'].apply(lambda x: tokenizer.tokenize(x) if isinstance(x, str) else [])


encoded_reviews = random_sample['review_body'].apply(lambda x: tokenizer.encode_plus(
    x,
    add_special_tokens=True,
    max_length=1024,  # GPT-2 can handle longer sequences
    padding='max_length',
    truncation=True,
    return_attention_mask=True,
    return_tensors='pt'
))

encoded_headlines = random_sample['review_headline'].apply(lambda x: tokenizer.encode_plus(
    x,
    add_special_tokens=True,
    max_length=128,
    padding='max_length',
    truncation=True,
    return_attention_mask=True,
    return_tensors='pt'
))

random_sample['review_input_ids'] = encoded_reviews.apply(lambda x: x['input_ids'].squeeze())
random_sample['review_attention_mask'] = encoded_reviews.apply(lambda x: x['attention_mask'].squeeze())

random_sample['headline_input_ids'] = encoded_headlines.apply(lambda x: x['input_ids'].squeeze())
random_sample['headline_attention_mask'] = encoded_headlines.apply(lambda x: x['attention_mask'].squeeze())

# %%
def map_stars_to_sentiment(star_rating):
    if star_rating == 1:
        return 'terrible'
    elif star_rating == 2:
        return 'bad'
    elif star_rating == 3:
        return 'ok'
    elif star_rating == 4:
        return 'good'
    elif star_rating == 5:
        return 'great'
    else:
        return 'unknown'

random_sample['sentiment'] = random_sample['star_rating'].apply(map_stars_to_sentiment)

sentiment_mapping = {
    'terrible': 0,
    'bad': 1,
    'ok': 2,
    'good': 3,
    'great': 4
}

random_sample['sentiment_label'] = random_sample['sentiment'].map(sentiment_mapping)

sentiment_dummies = pd.get_dummies(random_sample['sentiment'], prefix='sentiment')
random_sample = pd.concat([random_sample, sentiment_dummies], axis=1)

print("\nSentiment Distribution:")
print(random_sample['sentiment'].value_counts())

print("\nSentiment Distribution (%):")
print(random_sample['sentiment'].value_counts(normalize=True) * 100)
# Out:
# Sentiment Distribution:
# sentiment
# great       5910
# good        1906
# terrible     942
# ok           754
# bad          487
# Name: count, dtype: int64
#
# Sentiment Distribution (%):
# sentiment
# great       59.105911
# good        19.061906
# terrible     9.420942
# ok           7.540754
# bad          4.870487
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

# Function to pad sequences to the same length
def pad_sequences(sequences, max_length=None):
    if max_length is None:
        max_length = max(len(seq) for seq in sequences)
    
    padded_sequences = []
    for seq in sequences:
        if len(seq) > max_length:
            padded_seq = seq[:max_length]
        else:
            padding = np.zeros(max_length - len(seq))
            padded_seq = np.concatenate([seq, padding])
        padded_sequences.append(padded_seq)
    
    return np.array(padded_sequences)
# Out:
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Review Body - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       181
#            1       0.00      0.00      0.00        84
#            2       0.05      0.01      0.02       170
#            3       0.27      0.05      0.09       383
#            4       0.60      0.94      0.73      1182
#
#     accuracy                           0.57      2000
#    macro avg       0.18      0.20      0.17      2000
# weighted avg       0.41      0.57      0.45      2000
#
#
# Review Body - Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.25      0.01      0.01       181
#            1       0.00      0.00      0.00        84
#            2       0.00      0.00      0.00       170
#            3       0.29      0.02      0.03       383
#            4       0.59      0.99      0.74      1182
#
#     accuracy                           0.59      2000
#    macro avg       0.23      0.20      0.16      2000
# weighted avg       0.43      0.59      0.44      2000
#
#
# Headline - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       181
#            1       0.00      0.00      0.00        84
#            2       0.00      0.00      0.00       170
#            3       0.00      0.00      0.00       383
#            4       0.59      1.00      0.74      1182
#
#     accuracy                           0.59      2000
#    macro avg       0.12      0.20      0.15      2000
# weighted avg       0.35      0.59      0.44      2000
#
#
# Headline - Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.46      0.21      0.29       181
#            1       0.27      0.05      0.08        84
#            2       0.41      0.14      0.21       170
#            3       0.43      0.22      0.29       383
#            4       0.64      0.90      0.75      1182
#
#     accuracy                           0.61      2000
#    macro avg       0.44      0.30      0.32      2000
# weighted avg       0.55      0.61      0.55      2000
#
#
# Sample Review: 'This product exceeded my expectations'
# Predicted Sentiment: great
#
# Sample Headline: 'Amazing purchase'
# Predicted Sentiment: great
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Scotty Horvath\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ['best_headline_model.joblib']
